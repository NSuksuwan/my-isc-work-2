# %%
if []:
    print('hello')

#not gonna print anything since list[] is empty = false

# %%
if[1]:
    print('hello')
# Out:
# hello

# %%
foo = 6

# %%
while foo < 10:
    foo = foo +1 #checking
    print('hello')
# Out:
# hello
# hello
# hello
# hello
