# %%
#docstring
def average(values):
    "Return average of values, or None if no values are supplied."

    if len(values) == 0:
        return None
    return sum(values) / len(values)

help(average)
# Out:
# Help on function average in module __main__:
#
# average(values)
#     Return average of values, or None if no values are supplied.

# %%
#python only return one thing and exit

# %%
def example():
    return 'hello'
    return 'bye'
example()
# Out:
# 'hello'

# %%
def example():
    return 'hello', 'bye'
    
one, two = example() 
#tuple

# %%
one
# Out:
# 'hello'

# %%
two
# Out:
# 'bye'
