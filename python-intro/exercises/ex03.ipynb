# %%
print(type(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(type(i))
#
# NameError: name 'i' is not defined

# %%
print(type(52))
# Out:
# <class 'int'>

# %%
print(type(ii))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(type(ii))
#
# NameError: name 'ii' is not defined

# %%
age = ii
print(type(age))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 age = ii
#       2 print(type(age))
#
# NameError: name 'ii' is not defined

# %%
fitness = 'average'
print(type(fitness))
# Out:
# <class 'str'>

# %%
print('hello' - 'h')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print('hello' - 'h')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
print('hello' + 'h')
# Out:
# helloh

# %%
print('hello' * 'h')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print('hello' * 'h')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
full_name = 'Ahmed' + ' ' + 'Walsh'
print(full_name)
# Out:
# Ahmed Walsh

# %%
print(len(full_name))
# Out:
# 11

# %%
print(1 + int('2'))
print(str(1) + '2')
# Out:
# 3
# 12

# %%
var1 = "hello"
var2 = 100
var3 = 7.52
print(type(var1),type(var2),type(var3))
# Out:
# <class 'str'> <class 'int'> <class 'float'>

# %%
a = 2 ** 2 
b = 5.7 ** 2
print(type(a),type(b))
# Out:
# <class 'int'> <class 'float'>

# %%
n = "hello"
m = "world"

# %%
n - m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 n - m
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
n + m
# Out:
# 'helloworld'

# %%
'n' + 'm"
# Out:
#   Cell In[24], line 1
#     'n' + 'm"
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a = 3
b = 4
c = (a**2 + b**2) ** 0.5

# %%
print(int'c')
# Out:
#   Cell In[26], line 1
#     print(int'c')
#              ^
# SyntaxError: invalid syntax

# %%
print('c')
# Out:
# c

# %%
print(c)
# Out:
# 5.0

# %%
print(int('c'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(int('c'))
#
# ValueError: invalid literal for int() with base 10: 'c'

# %%
print(('a') + " squared equals " + str('b') + " squared " + str('c') + " squared.")
# Out:
# a squared equals b squared c squared.
