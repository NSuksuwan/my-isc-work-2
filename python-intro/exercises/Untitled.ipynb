# %%
import pandas as pd

# %%
import pandas as pd

print(ls(pandas))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
# ----> 3 print(ls(pandas))
#
# NameError: name 'ls' is not defined
