# %%
course = "python"
rating = "1"
print("course")
# Out:
# course

# %%
print(course)
# Out:
# python

# %%
print(course,rating)
# Out:
# python 1

# %%
(course,rating)
# Out:
# ('python', '1')

# %%
b = 3
c = 4
a = (b**2 + c**2)**0.5 
print(a)
# Out:
# 5.0

# %%
letter = "Centre for Environmental Data Analysis"
print(len(letter))
# Out:
# 38

# %%
print(letter[29:])
# Out:
#  Analysis

# %%
print(letter[11:25])
# Out:
# Environmental
